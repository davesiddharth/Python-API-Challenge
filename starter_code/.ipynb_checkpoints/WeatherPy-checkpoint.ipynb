# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import time

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combination
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = weather_api_key
units = "imperial"

query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

#print(query_url)

# %%
city_other = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        countries.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        
        if count_one > 49:
            count_one = 1
            set_one += 1
            city_other.append(city)
        else:
            count_one += 1
            city_other.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found.")
    time.sleep(0.1)
print("------------------------------Complete Data Retrieved------------------------------")
# Out:
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | hualmay
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | xichang
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | tiarei
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | adrar
# City not found.
# Processing Record 17 of Set 1 | machico
# Processing Record 18 of Set 1 | camana
# Processing Record 19 of Set 1 | karratha
# City not found.
# Processing Record 20 of Set 1 | tighina
# Processing Record 21 of Set 1 | ryotsu
# Processing Record 22 of Set 1 | magistralnyy
# City not found.
# Processing Record 23 of Set 1 | vila franca do campo
# Processing Record 24 of Set 1 | lavrentiya
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | bodden town
# Processing Record 28 of Set 1 | gat
# City not found.
# Processing Record 29 of Set 1 | hilo
# City not found.
# Processing Record 30 of Set 1 | cururupu
# Processing Record 31 of Set 1 | balkhash
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | saint-philippe
# City not found.
# Processing Record 34 of Set 1 | monte alegre
# Processing Record 35 of Set 1 | morgan city
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | hofn
# Processing Record 39 of Set 1 | grand river south east
# City not found.
# Processing Record 40 of Set 1 | sao filipe
# City not found.
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | nemuro
# Processing Record 44 of Set 1 | englewood
# Processing Record 45 of Set 1 | new norfolk
# City not found.
# Processing Record 46 of Set 1 | malanje
# Processing Record 47 of Set 1 | richards bay
# Processing Record 48 of Set 1 | vanimo
# Processing Record 49 of Set 1 | eyl
# Processing Record 50 of Set 1 | yerbogachen
# Processing Record 1 of Set 2 | lorengau
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | acapulco
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | lavagna
# Processing Record 9 of Set 2 | alofi
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | mbuji-mayi
# Processing Record 12 of Set 2 | benguela
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | shaunavon
# Processing Record 19 of Set 2 | lubango
# Processing Record 20 of Set 2 | fort smith
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | sayyan
# Processing Record 24 of Set 2 | praya
# Processing Record 25 of Set 2 | hambantota
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | inverell
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | sidney
# Processing Record 31 of Set 2 | tigre
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | panzhihua
# Processing Record 35 of Set 2 | fort nelson
# City not found.
# Processing Record 36 of Set 2 | ovsyanka
# Processing Record 37 of Set 2 | vagur
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | moron
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | sande
# Processing Record 43 of Set 2 | parati
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | sayansk
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | fairbanks
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | port-gentil
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | keflavik
# Processing Record 5 of Set 3 | mareeba
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | angleton
# Processing Record 8 of Set 3 | delta del tigre
# Processing Record 9 of Set 3 | turukhansk
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | palana
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | iquique
# Processing Record 15 of Set 3 | iaciara
# Processing Record 16 of Set 3 | warri
# Processing Record 17 of Set 3 | stettler
# Processing Record 18 of Set 3 | upernavik
# City not found.
# City not found.
# City not found.
# Processing Record 19 of Set 3 | gotsu
# Processing Record 20 of Set 3 | dalbandin
# Processing Record 21 of Set 3 | necochea
# Processing Record 22 of Set 3 | peniche
# City not found.
# Processing Record 23 of Set 3 | severnoye
# Processing Record 24 of Set 3 | hobyo
# Processing Record 25 of Set 3 | bulgan
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | teguise
# Processing Record 29 of Set 3 | ugoofaaru
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | cape elizabeth
# Processing Record 33 of Set 3 | padang
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | gamba
# Processing Record 36 of Set 3 | antofagasta
# Processing Record 37 of Set 3 | felanitx
# Processing Record 38 of Set 3 | maceio
# Processing Record 39 of Set 3 | puerto escondido
# City not found.
# Processing Record 40 of Set 3 | shingu
# Processing Record 41 of Set 3 | lapua
# Processing Record 42 of Set 3 | wadi musa
# City not found.
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | asau
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | skjervoy
# Processing Record 48 of Set 3 | egvekinot
# City not found.
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | kloulklubed
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | grand forks
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | cap-aux-meules
# Processing Record 6 of Set 4 | harper
# Processing Record 7 of Set 4 | beberibe
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 | festus
# City not found.
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | plouzane
# Processing Record 12 of Set 4 | raudeberg
# Processing Record 13 of Set 4 | belmonte
# Processing Record 14 of Set 4 | asuncion nochixtlan
# Processing Record 15 of Set 4 | yulara
# Processing Record 16 of Set 4 | olafsvik
# Processing Record 17 of Set 4 | zhigansk
# Processing Record 18 of Set 4 | atar
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | nambucca heads
# Processing Record 21 of Set 4 | pithapuram
# Processing Record 22 of Set 4 | khomutovo
# Processing Record 23 of Set 4 | cabra
# Processing Record 24 of Set 4 | aden
# Processing Record 25 of Set 4 | eureka
# City not found.
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | minab
# Processing Record 28 of Set 4 | samana
# Processing Record 29 of Set 4 | gombe
# Processing Record 30 of Set 4 | ambon
# Processing Record 31 of Set 4 | juegang
# Processing Record 32 of Set 4 | rocha
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | steinbach
# Processing Record 35 of Set 4 | bauchi
# Processing Record 36 of Set 4 | jiazi
# Processing Record 37 of Set 4 | mys shmidta
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | pemangkat
# Processing Record 41 of Set 4 | cayenne
# Processing Record 42 of Set 4 | aksarka
# Processing Record 43 of Set 4 | pacific grove
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | cortez
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | jalu
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | kailua
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | ordynskoye
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | carutapera
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | fukue
# Processing Record 8 of Set 5 | pierre
# Processing Record 9 of Set 5 | saint-pierre
# Processing Record 10 of Set 5 | gao
# Processing Record 11 of Set 5 | samarai
# City not found.
# Processing Record 12 of Set 5 | progreso
# Processing Record 13 of Set 5 | wewak
# Processing Record 14 of Set 5 | havelock
# Processing Record 15 of Set 5 | sao joao da barra
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | kandrian
# Processing Record 18 of Set 5 | bur gabo
# Processing Record 19 of Set 5 | mildura
# Processing Record 20 of Set 5 | baglung
# Processing Record 21 of Set 5 | beyneu
# City not found.
# Processing Record 22 of Set 5 | ponta delgada
# Processing Record 23 of Set 5 | taoudenni
# City not found.
# Processing Record 24 of Set 5 | nanortalik
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | gizo
# Processing Record 27 of Set 5 | muroto
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | hirara
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | partenit
# City not found.
# City not found.
# Processing Record 32 of Set 5 | honningsvag
# Processing Record 33 of Set 5 | nelson bay
# Processing Record 34 of Set 5 | gazanjyk
# Processing Record 35 of Set 5 | ferme-neuve
# Processing Record 36 of Set 5 | ishigaki
# City not found.
# Processing Record 37 of Set 5 | lasa
# Processing Record 38 of Set 5 | praia
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | dulce grande
# Processing Record 41 of Set 5 | nyurba
# Processing Record 42 of Set 5 | port blair
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | sola
# Processing Record 45 of Set 5 | daru
# Processing Record 46 of Set 5 | teknaf
# Processing Record 47 of Set 5 | kruisfontein
# Processing Record 48 of Set 5 | kahului
# Processing Record 49 of Set 5 | puerto del rosario
# Processing Record 50 of Set 5 | sambava
# Processing Record 1 of Set 6 | matagami
# Processing Record 2 of Set 6 | terney
# Processing Record 3 of Set 6 | petrozavodsk
# Processing Record 4 of Set 6 | korla
# Processing Record 5 of Set 6 | gillette
# City not found.
# Processing Record 6 of Set 6 | beringovskiy
# Processing Record 7 of Set 6 | mtwara
# Processing Record 8 of Set 6 | umba
# Processing Record 9 of Set 6 | kil
# Processing Record 10 of Set 6 | hukuntsi
# City not found.
# Processing Record 11 of Set 6 | dingle
# Processing Record 12 of Set 6 | norfolk
# Processing Record 13 of Set 6 | luanda
# Processing Record 14 of Set 6 | chuy
# Processing Record 15 of Set 6 | liku
# Processing Record 16 of Set 6 | lingyuan
# Processing Record 17 of Set 6 | chitrakonda
# Processing Record 18 of Set 6 | khash
# Processing Record 19 of Set 6 | lebyazhye
# Processing Record 20 of Set 6 | tiksi
# Processing Record 21 of Set 6 | banda aceh
# Processing Record 22 of Set 6 | seoul
# City not found.
# Processing Record 23 of Set 6 | isla vista
# Processing Record 24 of Set 6 | akdepe
# Processing Record 25 of Set 6 | terrace bay
# City not found.
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | vila velha
# Processing Record 28 of Set 6 | khasan
# Processing Record 29 of Set 6 | nuevo progreso
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | severo-kurilsk
# Processing Record 32 of Set 6 | izumo
# Processing Record 33 of Set 6 | port moresby
# Processing Record 34 of Set 6 | amalapuram
# Processing Record 35 of Set 6 | pajapan
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | neiafu
# Processing Record 38 of Set 6 | granada
# City not found.
# Processing Record 39 of Set 6 | nome
# City not found.
# Processing Record 40 of Set 6 | porto novo
# Processing Record 41 of Set 6 | mbandaka
# City not found.
# Processing Record 42 of Set 6 | omboue
# Processing Record 43 of Set 6 | quelimane
# Processing Record 44 of Set 6 | zapolyarnyy
# Processing Record 45 of Set 6 | parangan
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | atherton
# Processing Record 49 of Set 6 | along
# Processing Record 50 of Set 6 | spornoye
# Processing Record 1 of Set 7 | aqtobe
# City not found.
# City not found.
# Processing Record 2 of Set 7 | kochi
# Processing Record 3 of Set 7 | khandyga
# Processing Record 4 of Set 7 | anchorage
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | bose
# Processing Record 7 of Set 7 | kamaishi
# Processing Record 8 of Set 7 | mecca
# Processing Record 9 of Set 7 | iranduba
# City not found.
# City not found.
# Processing Record 10 of Set 7 | tias
# City not found.
# Processing Record 11 of Set 7 | high level
# Processing Record 12 of Set 7 | bara
# Processing Record 13 of Set 7 | peachland
# Processing Record 14 of Set 7 | bonthe
# City not found.
# Processing Record 15 of Set 7 | san vicente
# Processing Record 16 of Set 7 | moranbah
# Processing Record 17 of Set 7 | taboga
# Processing Record 18 of Set 7 | shimoda
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | dindori
# Processing Record 21 of Set 7 | moose factory
# Processing Record 22 of Set 7 | takaka
# Processing Record 23 of Set 7 | hovd
# Processing Record 24 of Set 7 | siyabuswa
# Processing Record 25 of Set 7 | kunming
# Processing Record 26 of Set 7 | katsuura
# Processing Record 27 of Set 7 | temuco
# Processing Record 28 of Set 7 | grand gaube
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | tougan
# City not found.
# Processing Record 31 of Set 7 | viedma
# Processing Record 32 of Set 7 | mubarakpur
# Processing Record 33 of Set 7 | killybegs
# Processing Record 34 of Set 7 | arrecife
# Processing Record 35 of Set 7 | araouane
# Processing Record 36 of Set 7 | catacamas
# Processing Record 37 of Set 7 | cambridge
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | tazovskiy
# Processing Record 40 of Set 7 | syamzha
# Processing Record 41 of Set 7 | nanakuli
# Processing Record 42 of Set 7 | ampanihy
# Processing Record 43 of Set 7 | puerto el triunfo
# Processing Record 44 of Set 7 | muros
# Processing Record 45 of Set 7 | rio grande
# Processing Record 46 of Set 7 | aketi
# Processing Record 47 of Set 7 | kashi
# Processing Record 48 of Set 7 | wladyslawowo
# Processing Record 49 of Set 7 | kuytun
# Processing Record 50 of Set 7 | karur
# Processing Record 1 of Set 8 | alice springs
# City not found.
# City not found.
# Processing Record 2 of Set 8 | motygino
# Processing Record 3 of Set 8 | pangnirtung
# Processing Record 4 of Set 8 | garowe
# Processing Record 5 of Set 8 | tessalit
# Processing Record 6 of Set 8 | moerewa
# Processing Record 7 of Set 8 | sparbu
# Processing Record 8 of Set 8 | marsa matruh
# Processing Record 9 of Set 8 | lazaro cardenas
# Processing Record 10 of Set 8 | liverpool
# Processing Record 11 of Set 8 | sucua
# City not found.
# Processing Record 12 of Set 8 | siniscola
# Processing Record 13 of Set 8 | finschhafen
# Processing Record 14 of Set 8 | kaohsiung
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | huarmey
# Processing Record 17 of Set 8 | menongue
# Processing Record 18 of Set 8 | leiyang
# Processing Record 19 of Set 8 | valparaiso
# Processing Record 20 of Set 8 | sapang buho
# Processing Record 21 of Set 8 | victoria
# Processing Record 22 of Set 8 | marawi
# City not found.
# Processing Record 23 of Set 8 | gambettola
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | villa vazquez
# Processing Record 26 of Set 8 | guozhen
# Processing Record 27 of Set 8 | zolotukhino
# Processing Record 28 of Set 8 | puteyets
# Processing Record 29 of Set 8 | zhangye
# Processing Record 30 of Set 8 | qobustan
# Processing Record 31 of Set 8 | marzuq
# Processing Record 32 of Set 8 | nalut
# Processing Record 33 of Set 8 | lomovka
# Processing Record 34 of Set 8 | kiruna
# Processing Record 35 of Set 8 | mamallapuram
# Processing Record 36 of Set 8 | abapo
# City not found.
# Processing Record 37 of Set 8 | nizwa
# Processing Record 38 of Set 8 | challapata
# Processing Record 39 of Set 8 | sabang
# Processing Record 40 of Set 8 | acari
# Processing Record 41 of Set 8 | awbari
# Processing Record 42 of Set 8 | nicolas bravo
# Processing Record 43 of Set 8 | wattegama
# Processing Record 44 of Set 8 | almaznyy
# Processing Record 45 of Set 8 | apolda
# Processing Record 46 of Set 8 | rio gallegos
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | ulladulla
# Processing Record 49 of Set 8 | pulaski
# Processing Record 50 of Set 8 | anori
# Processing Record 1 of Set 9 | roma
# Processing Record 2 of Set 9 | tibati
# Processing Record 3 of Set 9 | klaksvik
# Processing Record 4 of Set 9 | arenillas
# Processing Record 5 of Set 9 | kaina
# Processing Record 6 of Set 9 | at-bashi
# Processing Record 7 of Set 9 | chernyshevsk
# Processing Record 8 of Set 9 | hargeysa
# Processing Record 9 of Set 9 | provideniya
# Processing Record 10 of Set 9 | eydhafushi
# Processing Record 11 of Set 9 | kieta
# Processing Record 12 of Set 9 | portland
# Processing Record 13 of Set 9 | warmbad
# Processing Record 14 of Set 9 | chase
# Processing Record 15 of Set 9 | koygorodok
# City not found.
# Processing Record 16 of Set 9 | union
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | rameswaram
# Processing Record 19 of Set 9 | knysna
# City not found.
# Processing Record 20 of Set 9 | olinda
# Processing Record 21 of Set 9 | faya
# Processing Record 22 of Set 9 | nuuk
# Processing Record 23 of Set 9 | keti bandar
# Processing Record 24 of Set 9 | nago
# Processing Record 25 of Set 9 | satana
# Processing Record 26 of Set 9 | kutum
# Processing Record 27 of Set 9 | binga
# Processing Record 28 of Set 9 | ishim
# Processing Record 29 of Set 9 | makakilo city
# Processing Record 30 of Set 9 | leh
# Processing Record 31 of Set 9 | athabasca
# Processing Record 32 of Set 9 | zhezkazgan
# City not found.
# Processing Record 33 of Set 9 | skagen
# Processing Record 34 of Set 9 | roald
# Processing Record 35 of Set 9 | bollnas
# Processing Record 36 of Set 9 | tagab
# City not found.
# Processing Record 37 of Set 9 | norsup
# City not found.
# Processing Record 38 of Set 9 | kirakira
# Processing Record 39 of Set 9 | semnan
# Processing Record 40 of Set 9 | forbes
# Processing Record 41 of Set 9 | byron bay
# Processing Record 42 of Set 9 | bansi
# City not found.
# Processing Record 43 of Set 9 | san jeronimo
# Processing Record 44 of Set 9 | lieksa
# Processing Record 45 of Set 9 | santa rosa
# Processing Record 46 of Set 9 | concarneau
# Processing Record 47 of Set 9 | sarny
# Processing Record 48 of Set 9 | coahuayana
# Processing Record 49 of Set 9 | kupang
# City not found.
# Processing Record 50 of Set 9 | gravelbourg
# Processing Record 1 of Set 10 | katobu
# Processing Record 2 of Set 10 | kholtoson
# Processing Record 3 of Set 10 | bozoum
# Processing Record 4 of Set 10 | yangambi
# Processing Record 5 of Set 10 | sarkand
# Processing Record 6 of Set 10 | moa
# Processing Record 7 of Set 10 | algiers
# Processing Record 8 of Set 10 | ostrovnoy
# Processing Record 9 of Set 10 | grindavik
# Processing Record 10 of Set 10 | koslan
# Processing Record 11 of Set 10 | mukhen
# Processing Record 12 of Set 10 | iquitos
# Processing Record 13 of Set 10 | clinton
# Processing Record 14 of Set 10 | chake chake
# City not found.
# City not found.
# Processing Record 15 of Set 10 | peterhead
# Processing Record 16 of Set 10 | matay
# Processing Record 17 of Set 10 | betioky
# Processing Record 18 of Set 10 | pangkalanbuun
# Processing Record 19 of Set 10 | ostrogozhsk
# Processing Record 20 of Set 10 | nioro
# Processing Record 21 of Set 10 | lincoln
# City not found.
# Processing Record 22 of Set 10 | mount gambier
# Processing Record 23 of Set 10 | berlevag
# Processing Record 24 of Set 10 | porto san giorgio
# Processing Record 25 of Set 10 | maniitsoq
# Processing Record 26 of Set 10 | parkovyy
# Processing Record 27 of Set 10 | russell
# City not found.
# Processing Record 28 of Set 10 | saint-denis
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | esperance
# Processing Record 31 of Set 10 | andenes
# City not found.
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | ajdabiya
# Processing Record 34 of Set 10 | oparino
# Processing Record 35 of Set 10 | tura
# Processing Record 36 of Set 10 | heihe
# Processing Record 37 of Set 10 | rio pardo de minas
# Processing Record 38 of Set 10 | apac
# City not found.
# City not found.
# Processing Record 39 of Set 10 | san cristobal
# Processing Record 40 of Set 10 | porbandar
# Processing Record 41 of Set 10 | aras
# Processing Record 42 of Set 10 | miri
# Processing Record 43 of Set 10 | zhuhai
# City not found.
# Processing Record 44 of Set 10 | altmunster
# Processing Record 45 of Set 10 | kyshtovka
# Processing Record 46 of Set 10 | plyussa
# Processing Record 47 of Set 10 | charlestown
# Processing Record 48 of Set 10 | lashio
# City not found.
# Processing Record 49 of Set 10 | sao gabriel
# Processing Record 50 of Set 10 | lai
# Processing Record 1 of Set 11 | mangit
# Processing Record 2 of Set 11 | napasar
# Processing Record 3 of Set 11 | bonavista
# Processing Record 4 of Set 11 | kondinskoye
# Processing Record 5 of Set 11 | yar-sale
# Processing Record 6 of Set 11 | morbach
# Processing Record 7 of Set 11 | marsh harbour
# Processing Record 8 of Set 11 | carroll
# Processing Record 9 of Set 11 | mount isa
# City not found.
# Processing Record 10 of Set 11 | waipawa
# Processing Record 11 of Set 11 | kemijarvi
# Processing Record 12 of Set 11 | puerto leguizamo
# Processing Record 13 of Set 11 | hinton
# Processing Record 14 of Set 11 | qasigiannguit
# Processing Record 15 of Set 11 | tabat
# Processing Record 16 of Set 11 | nanzhang
# Processing Record 17 of Set 11 | ketchikan
# City not found.
# Processing Record 18 of Set 11 | saravena
# Processing Record 19 of Set 11 | vila
# City not found.
# Processing Record 20 of Set 11 | ayan
# Processing Record 21 of Set 11 | port lincoln
# Processing Record 22 of Set 11 | mkushi
# Processing Record 23 of Set 11 | dunedin
# City not found.
# Processing Record 24 of Set 11 | fairview
# Processing Record 25 of Set 11 | luchenza
# Processing Record 26 of Set 11 | campos novos
# Processing Record 27 of Set 11 | honiara
# Processing Record 28 of Set 11 | naze
# City not found.
# Processing Record 29 of Set 11 | abbeville
# Processing Record 30 of Set 11 | selkirk
# Processing Record 31 of Set 11 | darnah
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | lander
# Processing Record 34 of Set 11 | abu zabad
# City not found.
# Processing Record 35 of Set 11 | pokhara
# Processing Record 36 of Set 11 | bandarbeyla
# Processing Record 37 of Set 11 | fare
# Processing Record 38 of Set 11 | monopoli
# Processing Record 39 of Set 11 | cabedelo
# City not found.
# Processing Record 40 of Set 11 | yuancheng
# Processing Record 41 of Set 11 | brewster
# City not found.
# Processing Record 42 of Set 11 | heinola
# Processing Record 43 of Set 11 | carballo
# Processing Record 44 of Set 11 | ichinohe
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | antalaha
# ------------------------------Complete Data Retrieved------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
len(wind_speeds)
# Out:
# 546

# %%
weather_df = pd.DataFrame(
    {
    "City": city_other,
    "Country": countries,
    "Date": dates,
    "Cloudiness": cloudiness,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
    }
)
weather_df.count()
# Out:
# City          546
# Country       546
# Date          546
# Cloudiness    546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
weather_df.head()
# Out:
#               City Country        Date  Cloudiness  Humidity    Lat     Lng  \
# 0          qaanaaq      GL  1584056449           0        44  77.48  -69.36
# 1           torbay      CA  1584056450          90        92  47.67  -52.73
# 2        cape town      CL  1584056450          75        53 -36.41  -71.90
# 3            kapaa      US  1584056412          90        88  22.08 -159.32
# 4  bambous virieux      MU  1584056450          75        94 -20.26   57.41
#
#    Max Temp  Wind Speed
# 0    -19.97        5.26
# 1     28.99        9.17
# 2     73.40       12.75
# 3     77.00       11.41
# 4     80.01        6.91

# %%
# Exporting to CSV

weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker='o',s=40, edgecolors= "black")
plt.title("City Latitude vs Max Temperature")

plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("Latitude VS Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a Scatter Plot for Lattitude vs Humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker='o', s=40, edgecolors= "black")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('Latitude VS Humidity Level.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a Scatter Plot for Lattitude vs Cloudiness
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker='o', s=40, edgecolors= "black")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('Latitude VS Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a Scatter Plot for Lattitude vs Cloudiness
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker='o', s=40, edgecolors= "black")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('Latitude VS Wind Speed.png')

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"]>0.01]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<-0.01]

northern_hemisphere.head()
southern_hemisphere.head()
# Out:
#               City Country        Date  Cloudiness  Humidity    Lat    Lng  \
# 2        cape town      CL  1584056450          75        53 -36.41 -71.90
# 4  bambous virieux      MU  1584056450          75        94 -20.26  57.41
# 6             lebu      CL  1584056451         100        98 -37.62 -73.65
# 8          hualmay      PE  1584056451           2        69 -11.10 -77.61
# 9   port elizabeth      CD  1584056451         100        73  -7.03  29.76
#
#    Max Temp  Wind Speed
# 2     73.40       12.75
# 4     80.01        6.91
# 6     58.50        3.36
# 8     74.01        4.88
# 9     76.21        5.66

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS North Hem Temperature.png")
# Out:
# The r-squared is: -0.850800844652382

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-55,85),fontsize=15,color="red")

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS South Hem Temperature.png")
# Out:
# The r-squared is: 0.5985782979987929

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

plt.ylabel("Humidity")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS North Hem Humidity.png")
# Out:
# The r-squared is: 0.2746394326534978

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")

plt.ylabel("Humidity")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS South Hem Humidity.png")
# Out:
# The r-squared is: 0.2740805296434254

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS North Hem Cloudiness.png")
# Out:
# The r-squared is: 0.35984269968878785

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS South Hem Cloudiness.png")
# Out:
# The r-squared is: 0.3887140786310667

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(0,40),fontsize=15,color="red")

plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS North Hem Cloudiness.png")
# Out:
# The r-squared is: 0.292088450725477

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
#plt.show()
print(f"The r-squared is: {(rvalue)}")

plt.savefig("Latitude VS South Hem Cloudiness.png")
# Out:
# The r-squared is: -0.043766337359598194
