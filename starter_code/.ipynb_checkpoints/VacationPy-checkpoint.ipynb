# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint
# %matplotlib

# Import API key
from api_keys import g_key
gmaps.configure(api_key = g_key)
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
output_data_file = "weather_df.csv"
# output_data_file

weather_df = pd.read_csv(output_data_file)

weather_df.head()
# Out:
#    Unnamed: 0             City Country        Date  Cloudiness  Humidity  \
# 0           0          qaanaaq      GL  1584056449           0        44
# 1           1           torbay      CA  1584056450          90        92
# 2           2        cape town      CL  1584056450          75        53
# 3           3            kapaa      US  1584056412          90        88
# 4           4  bambous virieux      MU  1584056450          75        94
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  77.48  -69.36    -19.97        5.26
# 1  47.67  -52.73     28.99        9.17
# 2 -36.41  -71.90     73.40       12.75
# 3  22.08 -159.32     77.00       11.41
# 4 -20.26   57.41     80.01        6.91

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = weather_df[["Lat", "Lng"]]
# locations

humidity = weather_df["Humidity"].astype(float)

fig = gmaps.figure()

heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                   dissipating=False, max_intensity=5,
                                   point_radius=1)

fig.add_layer(heatmap_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
new_weather_df = pd.DataFrame(weather_df, columns = ["City", "Max Temp", "Wind Speed", "Cloudiness"])

max_temp = (new_weather_df["Max Temp"] <= 80) & (new_weather_df["Max Temp"] > 70)
wind_speed = new_weather_df["Wind Speed"] < 10
cloudiness = new_weather_df["Cloudiness"] == 0

new_weather_df[max_temp & wind_speed & cloudiness].head()
# Out:
#            City  Max Temp  Wind Speed  Cloudiness
# 76     inverell     73.99        5.99           0
# 80        tigre     78.01        4.70           0
# 89        moron     78.01        5.82           0
# 170  pithapuram     78.24        1.83           0
# 205       airai     73.76        3.00           0

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(weather_df, columns=["City", "Country", "Lat", "Lng"])

hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#               City Country    Lat     Lng Hotel Name
# 0          qaanaaq      GL  77.48  -69.36
# 1           torbay      CA  47.67  -52.73
# 2        cape town      CL -36.41  -71.90
# 3            kapaa      US  22.08 -159.32
# 4  bambous virieux      MU -20.26   57.41

# %%
target_location = f"{hotel_df['Lat'][0]},{hotel_df['Lng'][0]}"
target_keyword = "hotel"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "location": target_location,
    "keyword": target_keyword,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
pprint(response.json())
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 77.4692867, 'lng': -69.2315911},
#                            'viewport': {'northeast': {'lat': 77.47071577989271,
#                                                       'lng': -69.23000472010729},
#                                         'southwest': {'lat': 77.46801612010727,
#                                                       'lng': -69.23270437989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '57948e4c8303f471d71d38f6ded198a566166cb0',
#               'name': 'Qaanaaq Hotel',
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105406142912184834854">Jens-Peter '
#                                                 'Kleist</a>'],
#                           'photo_reference': 'CmRaAAAAk-3uoPvPB3-2FRLFaNMsZFGqqOIThZ6x4FoQP1CXtfxKcDDyYYIyp6S5jHxiy5fmvGVXpzRtL-clI7fJKi928mORapiYDHQ6yw2VHCrhgiEoEsdb5YW8EKqGeow2KOV5EhCcBCmMaozYVKJvUbrGHkQdGhTM7dosX_0RE_WWUBwDevKxots04Q',
#                           'width': 4096}],
#               'place_id': 'ChIJ29xdXLvJNU4RF7Y_k7vClTY',
#               'plus_code': {'compound_code': 'FQ99+P9 Qaanaaq, Greenland',
#                             'global_code': 'C79GFQ99+P9'},
#               'rating': 4.7,
#               'reference': 'ChIJ29xdXLvJNU4RF7Y_k7vClTY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 26,
#               'vicinity': 'Qaanaaq'}],
#  'status': 'OK'}

# %%
hotel_df.iloc[0][0]
# Out:
# 'qaanaaq'

# %%
#creates a list to capture hotel_names to insert into dataframe
hotel_names = []

# params dictionary to update each iteration
params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]

    params["location"] = f"{lat},{lng}"

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    address = requests.get(base_url, params=params)
    
    # convert to json
    address = address.json()
    try:
        hotel_names.append(address['results'][0]['name'])
    except IndexError:
        hotel_names.append(np.nan)

# %%
hotel_names
# Out:
# ['Qaanaaq Hotel',
#  nan,
#  'Hotel Molino Viejo',
#  'Sheraton Kauai Resort at Coconut Beach',
#  'La Pirogue Mauritius',
#  'Hengifoss Guesthouse',
#  'Hotel Plaza Lebu',
#  'Hotel Angmagssalik',
#  'Hotel Villa Kitzia Huacho',
#  nan,
#  'Pebbles Inn',
#  'Holiday Inn Express Xichang City Center',
#  'Inubosaki Kanko Hotel',
#  'Le Rocher de Tahiti',
#  'Shelikof Lodge',
#  nan,
#  'Santa Cruz Village Hotel',
#  'Hotel Camaná Suites',
#  'ibis Styles Karratha',
#  'Отель-ресторан "Старый бастион"',
#  'Ryotsu Yamaki Hotel',
#  'Магистраль',
#  'Hotel Castrum Villae',
#  nan,
#  'Esplanade Hotel',
#  nan,
#  'The Thatched Cottage Inn',
#  'Desert Gat',
#  'Grand Naniloa Hotel Hilo - a DoubleTree by Hilton',
#  'Hotel Cururupu',
#  'Millenium',
#  'Los Cauquenes Resort & Spa',
#  "Pinpin d'Amour",
#  "L'appollu",
#  'Holiday Inn Express & Suites Jacksonville',
#  'Best Western Danbury/Bethel',
#  'Frobisher Inn',
#  'Hotel Edda Höfn',
#  nan,
#  'Hotel Sai Residency',
#  'Paradise First Hotel',
#  'Hotel Pinomar',
#  'Hotel Nemuro Kaiyoutei',
#  'Courtyard by Marriott Denver Cherry Creek',
#  nan,
#  'Hotel Portugalia',
#  'Fairfield Inn & Suites by Marriott Detroit Lakes',
#  'Sandaun Surf Hotel',
#  'Amiin Hotel',
#  nan,
#  'Seeadler Bay Hotel',
#  'Saskylakh Aeroport',
#  "Pension Maro'i",
#  "Ellie's Villa",
#  'Holiday Inn Resort Acapulco',
#  nan,
#  nan,
#  'Hotel Ancora Riviera',
#  'Taloa Heights',
#  'Foveaux Hotel',
#  'Hotel Equinox',
#  'Aparthotel Mil Cidades',
#  "Mary-Ann's Polarrigg",
#  'The Explorer Hotel',
#  'Hotel Arctic',
#  'Gostinitsa "Zapolyar\'ye"',
#  'Mercure Bengkulu',
#  "Bear's Den Lodge",
#  'Residencial Dumas',
#  'Hotel Restaurant Ter Linde',
#  'Best Western Thompson Hotel & Suites',
#  nan,
#  nan,
#  'Hotel VIP Praia',
#  nan,
#  'LÜDERITZ NEST HOTEL',
#  'Inverell Motel',
#  'Coburn Hotel',
#  nan,
#  'Great Southern Hotel',
#  'Hotel Villa Victoria de Tigre',
#  "Munitsipal'naya Gostinitsa",
#  'Casa dos Lagos - AL',
#  'Chuanhui Grand Hotel',
#  'Hotel Restaurant Ter Linde',
#  nan,
#  'Vestmanna Hostel',
#  'Hotel Grand Chancellor Hobart',
#  'Carnarvon Central Apartments',
#  'Hotel Cabildo',
#  'Gran Hotel Suances',
#  'tauwerk Hotel',
#  'Apple Inn House Paraty',
#  nan,
#  'Hôtel Hiva Oa Hanakee Lodge',
#  'Yermak',
#  'End of The Road Ltd.',
#  'Best Western Plus Chena River Lodge',
#  'Chautauqua Harbor Hotel',
#  'Pension Residencial Victoria',
#  'Jimmy Hotel',
#  'Isles Sunset Lodge',
#  'Top of the World Hotel',
#  'Hotel Keflavik',
#  'Taj on Byrnes Mareeba Luxury Accommodation',
#  'Harbour House Hotel',
#  'Best Western Angleton Inn',
#  'Citrus Hotel & Suites',
#  'ООО "Туруханская пушнина"',
#  'Firlane House',
#  nan,
#  'Sundog Inn',
#  'Shanti Maurice Resort & Spa',
#  'ibis budget Iquique',
#  'Camargos Hotel',
#  'BON Hotel Delta',
#  'Ramada by Wyndham Stettler',
#  "Gina's Guesthouse - Upernavik",
#  'Super Hotel Gotsu Ekimae',
#  'Pakistan Hotel Dalbandin',
#  'Hotel Real',
#  'MH Peniche',
#  "Prem'yer",
#  nan,
#  'Bulgan Skytel',
#  nan,
#  'Tourist House - Sablino',
#  'B&B La Mimosa',
#  'Ungoofaaru Inn',
#  'Central Palace Hotel - Castro (PR)',
#  'THE REDWOOD RIVERWALK HOTEL',
#  'Hotel Molino Viejo',
#  'Mercure Padang',
#  'HOtel Tasiast',
#  nan,
#  'Hotel Terrado Suites Antofagasta',
#  'Petit Hotel Hostatgeria Sant Salvador',
#  'Jatiúca Hotel & Resort',
#  'Hotel Pinomar',
#  'Gran Hotel',
#  'Ravintola TexWilder',
#  nan,
#  'Panamericana Hotel Ancud',
#  'Pensiunea Sophia',
#  'Hotel Terraços da Beira (Trail Abutres)',
#  'Muri Beach Club Hotel Rarotonga',
#  'Hotel Maritim Skjervøy AS',
#  nan,
#  nan,
#  'The Adventures Inn-Peleliu',
#  'Lakeview Hotel Motel',
#  nan,
#  'Madero Aysen Hotel',
#  'Nusa Island Retreat',
#  "Motel L'Archipel Inc",
#  "Grands' Guesthouse",
#  'Pousada Ocas do Índio',
#  nan,
#  'Holiday Inn Express & Suites Festus - South St. Louis',
#  'Embassy Beach',
#  'Hôtel Restaurant du Bois',
#  'Ulvesund FYR',
#  'Pousada Rio',
#  'Crowne Plaza Asuncion',
#  'Desert Gardens Hotel - Ayers Rock Resort',
#  'Hotel Olafsvik',
#  'Gostinichnyy Kompleks Aylgy',
#  'Auberge mer et desert',
#  'Blue Heaven Island',
#  'Ingenia Holidays White Albatross',
#  nan,
#  nan,
#  'Hotel Mitra',
#  'Coral Hotel Aden',
#  'Best Western Plus Bayshore Inn',
#  'Darbat Hotel',
#  'Khone Ahmad',
#  'Figaro Hotel Boutique Samana',
#  'Custodian Hotel Gombe',
#  'Orchid Hotel',
#  'Landison Hotel Nantong',
#  'Casa Rodo 53',
#  'Hotel Intercity Suape Costa Dourada',
#  'Dorint Hotel Frankfurt Oberursel',
#  nan,
#  'Bohai Hotel',
#  nan,
#  'Waiau Hotel',
#  'Eastern & Oriental Hotel, Penang',
#  'Grand Hotel',
#  'Guyane Hôtel',
#  nan,
#  'Comfort Inn Near Six Flags St. Louis',
#  'Aspen Suites Hotel Haines',
#  'Preskil Island Resort',
#  'Hotel Playa El Cable',
#  'Holiday Inn Express Mesa Verde-Cortez',
#  'Talon Lodge & Spa',
#  'Jalu Hotel',
#  'OURE TERA beach resort',
#  nan,
#  nan,
#  nan,
#  'Hoedjiesbaai Hotel',
#  'HOTEL R. SOARES',
#  nan,
#  'Goto Guest House Utojuku',
#  'Super 8 by Wyndham Pierre SD',
#  'Le Battant Des Lames',
#  nan,
#  'Nuli Sapi',
#  'Playa Linda Hotel',
#  'In Wewak Boutique Hotel',
#  'Holiday Inn Express & Suites Havelock NW-New Bern',
#  'Hotel Sai Residency',
#  'Hilton Garden Inn Norman',
#  nan,
#  'Plexus Hytterne',
#  'Quality Hotel Mildura Grand',
#  'Hotel Peace Palace, Baglung, Nepal',
#  'NUR',
#  'Casa dos Lagos - AL',
#  nan,
#  'Hotel Kap Farvel',
#  nan,
#  'Oravae Island Cottages',
#  'ウトコ オーベルジュ＆スパ',
#  "The Trainmaster's Inn",
#  'HOTEL LOCUS',
#  'Ocean Centre Hotel',
#  'Europe',
#  'Nordkapp Vandrerhjem',
#  'Trailways Hotel',
#  nan,
#  'Pourvoirie Club Fontbrune Ltee',
#  'Fusaki Beach Resort Hotel & Villas',
#  'Untertelshof',
#  'Hotel VIP Praia',
#  nan,
#  'Wild Horse Casino & Hotel',
#  'Gostinitsa Alrosa',
#  nan,
#  nan,
#  nan,
#  'Daru hotel',
#  'Milky Resort',
#  nan,
#  'Maui Beach Hotel',
#  'Hotel Puertobahia & Spa',
#  'Carrefour',
#  'Hôtel Matagami',
#  'Hotel "Ternay"',
#  'Otel\' "Fregat"',
#  '7 Days Inn Korla Coach Station Branch',
#  'Days Inn by Wyndham Gillette',
#  'Beringgorski',
#  'Luwa Evergreen Hotel',
#  'Cedar Grass Beloye More',
#  'Sköna Rum Fryksta',
#  'Entabeni Hotel',
#  nan,
#  'Best Western Plus The Inn at Sharon/Foxboro',
#  'Hotel Presidente Luanda',
#  'Turis Firper Hotel',
#  nan,
#  'Lingyuan International Hotel',
#  nan,
#  'خوابگاه دانشجویی خاش',
#  nan,
#  'Gostinitsa',
#  'Hotel Sarang Intercontinental',
#  'K-POP HOTEL Seoul Tower',
#  nan,
#  nan,
#  'Holiday Inn Express & Suites Terrace',
#  'Hôtel Teriya',
#  'Hotel Castrum Villae',
#  nan,
#  nan,
#  'Red Roof Inn Clyde',
#  'Kak Doma',
#  'Izumo Royal Hotel',
#  nan,
#  'Hotel satkar',
#  'Hotel Del Carmen',
#  'Codrington Gardens Bed And Breakfast',
#  'Puataukanave International Hotel',
#  nan,
#  'Nome Nugget Inn',
#  'Hotel da Bolsa',
#  'Nina River Hotel',
#  'Hotel Olako',
#  'Hotel Elite',
#  'Pechenga',
#  nan,
#  'Igdlo Guesthouse',
#  'Pond Country Club',
#  'Holiday Inn Express - Leigh Sports Village',
#  'Hotel Min-Ta',
#  nan,
#  'Royal Hotel',
#  'Zostel',
#  "Apel'sin",
#  'The Lakefront Anchorage',
#  'Manmimar Nature Lodge',
#  "Villa D'Azeglio",
#  'Hotel Folkloro Sanriku Kamaishi',
#  'Pullman Zamzam Makkah',
#  nan,
#  'Puerto Carmen Hotel - RIVERSUN-TOURISTIC',
#  nan,
#  nan,
#  nan,
#  'Bonthe Holiday Village',
#  'Hôtel Teriya',
#  'Moranbah Motor Inn',
#  'Al Castello',
#  'Hotel Izukyu',
#  'Sands Hotel Margate',
#  'Hotel Asha residence',
#  nan,
#  'The Rocks Chalets',
#  'Minj Hotel',
#  nan,
#  'Royal Garden Hotel',
#  'Katsuura Hotel Mikazuki',
#  'Hotel Diego de Almagro Temuco',
#  nan,
#  'Hotel Ilha Graciosa',
#  "Hotel de l'avenir",
#  'Hotel Austral Viedma',
#  nan,
#  'Tara Hotel',
#  'Arrecife Gran Hotel & Spa',
#  nan,
#  'Hotel Papabeto',
#  'Langdon Hall Country House Hotel & Spa',
#  'Talnakh Hotel',
#  'Hotel Tazovchanka',
#  'Inn Slavyanskaya',
#  nan,
#  'Angora Hotel',
#  'Hotel Pinomar',
#  'O Prouso',
#  'PORTO RIO HOTEL & CASINO',
#  nan,
#  'Radisson Blu Hotel Kashgar',
#  'Hotel Faleza Rozewie',
#  'Zhemchug',
#  'Hotel Hemala',
#  'La Quinta Inn & Suites by Wyndham Alice',
#  'Gostinitsa Ip Zabirov',
#  'Auyuittuq Lodge (Inns North)',
#  'Grand Hotel',
#  nan,
#  nan,
#  nan,
#  'Preluna',
#  'Hotel Marien',
#  'Adelphi Hotel',
#  'hosteria luzcelinda',
#  'Hotel Velasole',
#  'Cossam Guest House',
#  'WO Hotel (窩飯店)',
#  'Atlantis Hotel',
#  'El Mana',
#  'Hotel Ritz Lauca',
#  '7 Days Inn',
#  'Hotel Palacio Astoreca',
#  nan,
#  'The Harbourview',
#  'Marawi Resort Hotel',
#  'Hotel Rubicone',
#  nan,
#  'Albergo Stazione',
#  'Yucai Hotel',
#  'Kamushki',
#  'Hotel Alfa',
#  'Holiday Inn Express Zhangye',
#  nan,
#  nan,
#  nan,
#  'Manor Hotel',
#  'Camp Ripan',
#  'Rajalakshmi Guesthouse',
#  nan,
#  'Antique Inn - Nizwa',
#  'Residencial Cory',
#  'Casa Nemo Beach Resort & Spa',
#  'Hostal Mi Refugio',
#  nan,
#  'Regi Hotel & Bar',
#  nan,
#  'Gostinitsa Zverevo',
#  'Hotel am Schloß Apolda',
#  'PORTO RIO HOTEL & CASINO',
#  nan,
#  'Bannisters by the Sea',
#  'DoubleTree by Hilton Hotel Little Rock',
#  'Hotel Central',
#  'Wingate By Wyndham Rome',
#  'Tibati Hotel',
#  'Hotel Klaksvík',
#  'Casa del Curato',
#  nan,
#  'Hostel At-Bashy',
#  'Mini Gostinitsa "Kak Doma"',
#  'Maamuus Hotel Hargeisa',
#  nan,
#  'Dhonfulhafi Beach View & Spa',
#  nan,
#  'The Society Hotel - Portland',
#  nan,
#  'Jade Mountain Motel',
#  nan,
#  'Hotel Executive Suites',
#  'Hotel "ADRAS" Гостиницы',
#  'Hotel Rameswaram Grand',
#  'Pezula Resort Hotel & Spa',
#  'Hotel Costeiro Olinda',
#  nan,
#  "Hotel Seamen's Home",
#  'Erazank Hotel',
#  'Bamboo Japanese Style Inn',
#  'Jai Jai Gaurishankar Hotel',
#  nan,
#  'Masumu River Lodge',
#  'visit Hotel',
#  'Four Seasons Resort Oahu at Ko Olina',
#  'The Grand Dragon Ladakh',
#  'Days Inn by Wyndham Athabasca',
#  'Hotel Zumrat',
#  'Brøndums Hotel',
#  'Vestavind Hytter og Rom AS',
#  'Grand Hotel',
#  nan,
#  'Lakatoro Palm Lodge',
#  nan,
#  'Gootkemall Hotel',
#  'Lake Forbes Motel',
#  nan,
#  nan,
#  'Hôtel Teriya',
#  'Kaatrahovi',
#  nan,
#  'Les Sables Blancs',
#  'Park Hotel Warshawskiy',
#  'Hotel Los Arcos',
#  'ASTON Kupang Hotel & Convention Center',
#  'Heritage Place B&B',
#  'Balai Desa Kafofo',
#  nan,
#  nan,
#  nan,
#  'Гостиница Сарканд',
#  'Miraflores',
#  'Sofitel Algiers Hamma Garden',
#  nan,
#  'Mar Guesthouse',
#  nan,
#  nan,
#  'Cumaceba Amazon Experience',
#  'TownePlace Suites by Marriott Detroit Sterling Heights',
#  nan,
#  'Palace Hotel',
#  nan,
#  'Betioky',
#  'Grand Kecubung Hotel',
#  'Hotel Lushnikovskaya',
#  nan,
#  'The Lincoln Marriott Cornhusker Hotel',
#  'Travelodge Huddersfield',
#  'Berlevåg camping & Appartement AS',
#  'Hotel da Bolsa',
#  'Hotel Maniitsoq',
#  'Hotel Elegans',
#  nan,
#  'Hôtel Darcet',
#  nan,
#  'The Jetty Resort',
#  'Andrikken Hotel',
#  nan,
#  'Ajdabiya Hotel',
#  'Gostinitsa',
#  'Hotel Polo Orchid',
#  'Mercure Blagoveshchensk',
#  'PORTO RIO HOTEL & CASINO',
#  'A ONE HOTEL',
#  'Hôtel Teriya',
#  'Hotel Kuber',
#  'Jardines de Viana Spa',
#  'Meritz Hotel, Miri, Sarawak.',
#  'Pullman Zhuhai',
#  'Altmünsterhof',
#  'Uyutnaya Mini-Hotel',
#  'Service hotel',
#  'Hotel Jesmond',
#  'Mansu Hotel',
#  'Hotel Sai Residency',
#  nan,
#  'Dangara Hotel',
#  nan,
#  'Hotel Bonavista',
#  nan,
#  'Hotel "Nord House"',
#  '2tHEIMAT',
#  'Travelodge Huddersfield',
#  'Days Inn by Wyndham Westminster',
#  'Travelodge Huddersfield',
#  nan,
#  'Hotel Uitonniemi',
#  'Hotel Pinomar',
#  'Holiday Inn Hinton',
#  'Qasigiannguit',
#  nan,
#  'Peace Hotel',
#  'The Landing Hotel',
#  'hotel yaroan',
#  'Hotel Castrum Villae',
#  'Gostinitsa',
#  nan,
#  'Home',
#  'Distinction Dunedin Hotel',
#  'Hilton Garden Inn New York/Central Park South-Midtown West',
#  nan,
#  'Comfort Hotel Campos dos Goytacazes',
#  'Coral Sea Resort & Casino',
#  'Hotel New Amami',
#  "Le Jardin d'Adèle",
#  'Canalta Hotel Selkirk',
#  'Mountain Hotel',
#  'Hotel National',
#  'Holiday Inn Express & Suites Lander',
#  'Gorbandh Hotel',
#  'Himalayan Front Hotel',
#  'REER XOOSHLE GROUP',
#  'Huahine Yacht Club',
#  'Locanda Don Ferrante',
#  'Hotel Almagre',
#  nan,
#  "Heidi's Inn",
#  'hotel Kumpeli',
#  'Pazo do Souto',
#  nan,
#  'BISMI HOTEL',
#  'Villa-Malaza']

# %%
hotel_df['Hotel Name']= hotel_names
hotel_df.dropna()
hotel_df.head()
# Out:
#               City Country    Lat     Lng  \
# 0          qaanaaq      GL  77.48  -69.36
# 1           torbay      CA  47.67  -52.73
# 2        cape town      CL -36.41  -71.90
# 3            kapaa      US  22.08 -159.32
# 4  bambous virieux      MU -20.26   57.41
#
#                                Hotel Name
# 0                           Qaanaaq Hotel
# 1                                     NaN
# 2                      Hotel Molino Viejo
# 3  Sheraton Kauai Resort at Coconut Beach
# 4                    La Pirogue Mauritius

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
